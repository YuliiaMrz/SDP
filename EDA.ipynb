# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn import metrics

#import warnings
#warnings.filterwarnings('ignore')

#plt.style.use('ggplot')
#pd.options.display.max_rows = 200

# %%
df = pd.read_csv(r"C:/Users/Yuliia/Desktop/SDP/Project/Google_dataset.csv")

# %%
df.shape
# Out:
# (4979, 7)

# %%
df.tail(10)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 4969  16/05/2024  174.600006  176.339996  174.050003  175.429993  175.429993
# 4970  17/05/2024  175.550003  177.494995  174.979996  177.289993  177.289993
# 4971  20/05/2024  177.309998  179.949997  177.225006  178.460007  178.460007
# 4972  21/05/2024  178.399994  179.820007  177.309998  179.539993  179.539993
# 4973  22/05/2024  178.399994  178.852005  176.779999  178.000000  178.000000
# 4974  23/05/2024  178.779999  179.910004  174.539993  175.059998  175.059998
# 4975  24/05/2024  176.520004  177.304001  175.199997  176.330002  176.330002
# 4976  28/05/2024  175.740005  178.509995  175.679993  178.020004  178.020004
# 4977  29/05/2024  176.809998  178.229996  176.259995  177.399994  177.399994
# 4978  30/05/2024  176.589996  176.619995  174.060104  174.229996  174.229996
#
#         Volume
# 4969  17247300
# 4970  16546400
# 4971  17495100
# 4972  14706000
# 4973  16189400
# 4974  14928400
# 4975  11400600
# 4976  15655300
# 4977  15005100
# 4978   9274471

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  4979.000000  4979.000000  4979.000000  4979.000000  4979.000000
# mean     44.134588    44.601841    43.693217    44.158258    44.158258
# std      41.721621    42.190265    41.311671    41.763394    41.763394
# min       2.470490     2.534002     2.390042     2.490913     2.490913
# 25%      12.958927    13.121318    12.835763    12.979101    12.979101
# 50%      26.892168    27.060205    26.660454    26.892000    26.892000
# 75%      59.597250    60.023251    59.148251    59.646252    59.646252
# max     178.779999   179.949997   177.309998   179.539993   179.539993
#
#              Volume
# count  4.979000e+03
# mean   1.165609e+08
# std    1.501420e+08
# min    1.584340e+05
# 25%    2.770700e+07
# 50%    5.727789e+07
# 75%    1.443551e+08
# max    1.650833e+09

# %%
df[['Date', 
    #'Open',
    #'High',
    #'Low', 
    'Close',
    'Adj Close',
    'Volume']].head(20).copy()
# Out:
#           Date     Close  Adj Close     Volume
# 0   19/08/2004  2.499133   2.499133  897427216
# 1   20/08/2004  2.697639   2.697639  458857488
# 2   23/08/2004  2.724787   2.724787  366857939
# 3   24/08/2004  2.611960   2.611960  306396159
# 4   25/08/2004  2.640104   2.640104  184645512
# 5   26/08/2004  2.687676   2.687676  142572401
# 6   27/08/2004  2.643840   2.643840  124826132
# 7   30/08/2004  2.540727   2.540727  104429967
# 8   31/08/2004  2.549693   2.549693   98825037
# 9   01/09/2004  2.496891   2.496891  183633734
# 10  02/09/2004  2.528273   2.528273  303810504
# 11  03/09/2004  2.490913   2.490913  103538639
# 12  07/09/2004  2.530017   2.530017  117506800
# 13  08/09/2004  2.547950   2.547950  100186120
# 14  09/09/2004  2.548199   2.548199   81620792
# 15  10/09/2004  2.623417   2.623417  174804764
# 16  13/09/2004  2.677464   2.677464  157628624
# 17  14/09/2004  2.776842   2.776842  217608605
# 18  15/09/2004  2.789544   2.789544  215279909
# 19  16/09/2004  2.838610   2.838610  186207345

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# df.loc[df.duplicated()]
df['Date'] = pd.to_datetime(df['Date'], dayfirst = True)

# %%
df = df[['Date', 'Close', 'Volume']].tail(20)

# df.plot(kind = 'scatter',
     # x = 'Date',
     # y = 'Close',
     # title = 'Close through the years')
# plt.show()

# %%
sns.scatterplot(x = 'Date',
                y = 'Close',
                hue = 'Close',
                data = df)
plt.show()

# %%
sns.pairplot(df, vars = ['Close', 'Volume'])
plt.show()
